# %%
result = client.images.edit(
    model="gpt-image-1",
    image=open("original.png", "rb"),
    mask=open("mask.png", "rb"),
    prompt="Change the background to a starry night sky"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 result = client.images.edit(
#       2     model="gpt-image-1",
#       3     image=open("original.png", "rb"),
#       4     mask=open("mask.png", "rb"),
#       5     prompt="Change the background to a starry night sky"
#       6 )
#
# NameError: name 'client' is not defined

# %%
result = client.images.edit(
    model="gpt-image-1",
    image=open("original.png", "rb"),
    mask=open("mask.png", "rb"),
    prompt="Change the background to a starry night sky"
)
